# %% [markdown]
# ## WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# # Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create empty lists and counters for record and set

city_name = []
latitude = []
longitude = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
countries = []
date_time = []
record_counter = 0
set_counter = 1

# Print initial output as shown

print("Beginning Data Retrieval")
print("-----------------------------")

# Construct query URL

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

# Create for loop

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        countries.append(response["sys"]["country"])
        date_time.append(response["dt"])
        
        if record_counter > 48:
            record_counter = 0
            set_counter = set_counter + 1
        
        else:
            record_counter = record_counter + 1
        
        print(f"Processing Record {record_counter} of Set {set_counter} | {city}")
        
    except (KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | husavik
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | beloha
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | constitucion
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | cabo san lucas
# Processing Record 10 of Set 1 | turayf
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | chuy
# Processing Record 14 of Set 1 | dobrinka
# Processing Record 15 of Set 1 | puerto escondido
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | mkushi
# Processing Record 20 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | aksu
# Processing Record 25 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | jibuti
# Processing Record 30 of Set 1 | kahului
# Processing Record 31 of Set 1 | barrow
# City not found. Skipping...
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | asbury park
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | mazyr
# Processing Record 36 of Set 1 | airai
# Processing Record 37 of Set 1 | tateyama
# Processing Record 38 of Set 1 | hasaki
# Processing Record 39 of Set 1 | kavieng
# Processing Record 40 of Set 1 | trairi
# Processing Record 41 of Set 1 | sibolga
# Processing Record 42 of Set 1 | upernavik
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | hovd
# Processing Record 45 of Set 1 | cotonou
# Processing Record 46 of Set 1 | kailua
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | severo-kurilsk
# Processing Record 49 of Set 1 | woodburn
# Processing Record 0 of Set 2 | terrace
# Processing Record 1 of Set 2 | banjar
# Processing Record 40 of Set 4 | naryan-mar
# Processing Record 41 of Set 4 | lagoa
# Processing Record 42 of Set 4 | isangel
# Processing Record 43 of Set 4 | talara
# Processing Record 44 of Set 4 | batesville
# City not found. Skipping...
# Processing Record 45 of Set 4 | lebu
# Processing Record 46 of Set 4 | kota bahru
# Processing Record 47 of Set 4 | yazman
# Processing Record 48 of Set 4 | san quintin
# Processing Record 49 of Set 4 | brokopondo
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 0 of Set 5 | stokmarknes
# Processing Record 1 of Set 5 | bridlington
# Processing Record 2 of Set 5 | aitape
# Processing Record 3 of Set 5 | harper
# Processing Record 4 of Set 5 | kovernino
# Processing Record 5 of Set 5 | acari
# Processing Record 6 of Set 5 | ribas do rio pardo
# Processing Record 7 of Set 5 | zhezkazgan
# Processing Record 8 of Set 5 | sitka
# Processing Record 9 of Set 5 | bellefontaine
# Processing Record 10 of Set 5 | nome
# Processing Record 11 of Set 5 | mardin
# Processing Record 12 of Set 5 | lukovetskiy
# Processing Record 13 of Set 5 | mount gambier
# Processing Record 14 of Set 5 | pisco
# Processing Record 15 of Set 5 | shagonar
# Processing Record 16 of Set 5 | uthal
# Processing Record 17 of Set 5 | matagami
# Processing Record 18 of Set 5 | rawson
# Processing Record 19 of Set 5 | cascais
# Processing Record 20 of Set 5 | meulaboh
# Processing Record 21 of Set 5 | dire dawa
# Processing Record 22 of Set 5 | taltal
# Processing Record 23 of Set 5 | verkhniy lomov
# Processing Record 24 of Set 5 | senneterre
# Processing Record 25 of Set 5 | thompson
# Processing Record 26 of Set 5 | iisalmi
# Processing Record 27 of Set 5 | coquimbo
# Processing Record 28 of Set 5 | sawtell
# Processing Record 29 of Set 5 | eenhana
# Processing Record 30 of Set 5 | nizhnevartovsk
# Processing Record 31 of Set 5 | tibati
# Processing Record 32 of Set 5 | monze
# Processing Record 33 of Set 5 | san jose
# Processing Record 34 of Set 5 | troitskoye
# Processing Record 35 of Set 5 | huntington
# Processing Record 36 of Set 5 | broome
# Processing Record 37 of Set 5 | paka
# Processing Record 38 of Set 5 | provideniya
# Processing Record 39 of Set 5 | tucurui
# Processing Record 40 of Set 5 | marquette
# City not found. Skipping...
# Processing Record 41 of Set 5 | kieta
# Processing Record 42 of Set 5 | palafrugell
# Processing Record 43 of Set 5 | los llanos de aridane
# Processing Record 44 of Set 5 | allapalli
# Processing Record 45 of Set 5 | duliagaon
# Processing Record 46 of Set 5 | grand island
# City not found. Skipping...
# Processing Record 47 of Set 5 | sahuaripa
# Processing Record 48 of Set 5 | sheregesh
# Processing Record 49 of Set 5 | paamiut
# Processing Record 0 of Set 6 | bintulu
# Processing Record 1 of Set 6 | northam
# Processing Record 2 of Set 6 | taoudenni
# City not found. Skipping...
# Processing Record 3 of Set 6 | arman
# City not found. Skipping...
# Processing Record 4 of Set 6 | port hedland
# Processing Record 5 of Set 6 | antalaha
# Processing Record 6 of Set 6 | catuday
# Processing Record 7 of Set 6 | skjervoy
# Processing Record 8 of Set 6 | khorixas
# Processing Record 9 of Set 6 | kavaratti
# Processing Record 10 of Set 6 | gerash
# City not found. Skipping...
# Processing Record 11 of Set 6 | kiruna
# Processing Record 12 of Set 6 | plettenberg bay
# Processing Record 13 of Set 6 | bajil
# Processing Record 14 of Set 6 | nantucket
# Processing Record 15 of Set 6 | ampanihy
# Processing Record 16 of Set 6 | nioro
# Processing Record 17 of Set 6 | saint-philippe
# Processing Record 18 of Set 6 | methala
# Processing Record 19 of Set 6 | lalganj
# Processing Record 20 of Set 6 | cabedelo
# Processing Record 21 of Set 6 | margate
# Processing Record 22 of Set 6 | bandarbeyla
# Processing Record 23 of Set 6 | shelburne
# Processing Record 24 of Set 6 | port hardy
# Processing Record 25 of Set 6 | pevek
# Processing Record 26 of Set 6 | inirida
# Processing Record 27 of Set 6 | hambantota
# Processing Record 28 of Set 6 | laguna
# Processing Record 29 of Set 6 | aklavik
# Processing Record 30 of Set 6 | kruisfontein
# Processing Record 31 of Set 6 | cherskiy
# Processing Record 32 of Set 6 | ciudad bolivar
# Processing Record 33 of Set 6 | richards bay
# Processing Record 34 of Set 6 | datong
# Processing Record 35 of Set 6 | assiniboia
# Processing Record 36 of Set 6 | coihaique
# Processing Record 37 of Set 6 | rocha
# Processing Record 38 of Set 6 | maningrida
# Processing Record 39 of Set 6 | cidreira
# Processing Record 40 of Set 6 | fougamou
# Processing Record 41 of Set 6 | narsaq
# Processing Record 42 of Set 6 | mayskiy
# Processing Record 43 of Set 6 | benton harbor
# Processing Record 44 of Set 6 | san rafael del sur
# Processing Record 45 of Set 6 | vanavara
# Processing Record 46 of Set 6 | shenjiamen
# City not found. Skipping...
# Processing Record 47 of Set 6 | san policarpo
# Processing Record 48 of Set 6 | andenes
# Processing Record 49 of Set 6 | dabat
# Processing Record 0 of Set 7 | labuhan
# Processing Record 1 of Set 7 | rio grande
# Processing Record 2 of Set 7 | biak
# Processing Record 3 of Set 7 | russell
# Processing Record 4 of Set 7 | ascension
# Processing Record 5 of Set 7 | asyut
# Processing Record 6 of Set 7 | saint george
# City not found. Skipping...
# Processing Record 7 of Set 7 | sterling
# Processing Record 8 of Set 7 | shimoda
# Processing Record 9 of Set 7 | olafsvik
# Processing Record 10 of Set 7 | olga
# Processing Record 11 of Set 7 | abu dhabi
# Processing Record 12 of Set 7 | hualmay
# Processing Record 13 of Set 7 | yulara
# Processing Record 14 of Set 7 | port augusta
# Processing Record 15 of Set 7 | necochea
# Processing Record 16 of Set 7 | mandalgovi
# Processing Record 17 of Set 7 | kupang
# Processing Record 18 of Set 7 | qaqortoq
# Processing Record 19 of Set 7 | pychas
# Processing Record 20 of Set 7 | mildura
# Processing Record 21 of Set 7 | lorengau
# Processing Record 22 of Set 7 | beisfjord
# Processing Record 23 of Set 7 | nyimba
# Processing Record 24 of Set 7 | college
# City not found. Skipping...
# Processing Record 25 of Set 7 | norman wells
# Processing Record 26 of Set 7 | saint-leu
# Processing Record 27 of Set 7 | sulangan
# Processing Record 28 of Set 7 | hays
# Processing Record 29 of Set 7 | rock sound
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 47 of Set 8 | escanaba
# Processing Record 48 of Set 8 | geraldton
# Processing Record 49 of Set 8 | orchard homes
# Processing Record 0 of Set 9 | binzhou
# Processing Record 1 of Set 9 | ngaoundere
# Processing Record 2 of Set 9 | clinton
# Processing Record 3 of Set 9 | mathbaria
# City not found. Skipping...
# Processing Record 4 of Set 9 | vardo
# Processing Record 5 of Set 9 | storm lake
# Processing Record 6 of Set 9 | port-gentil
# Processing Record 7 of Set 9 | klyuchi
# Processing Record 8 of Set 9 | salinopolis
# Processing Record 9 of Set 9 | saint-francois
# Processing Record 10 of Set 9 | rohnert park
# Processing Record 11 of Set 9 | westport
# Processing Record 12 of Set 9 | saint-georges
# Processing Record 13 of Set 9 | key west
# Processing Record 14 of Set 9 | moundou
# Processing Record 15 of Set 9 | banyo
# Processing Record 16 of Set 9 | birin
# Processing Record 17 of Set 9 | karaton
# Processing Record 18 of Set 9 | camocim
# Processing Record 19 of Set 9 | pitimbu
# City not found. Skipping...
# Processing Record 20 of Set 9 | roma
# Processing Record 21 of Set 9 | nosy varika
# Processing Record 22 of Set 9 | zaysan
# Processing Record 23 of Set 9 | amahai
# Processing Record 24 of Set 9 | poum
# Processing Record 25 of Set 9 | tavagnacco
# Processing Record 26 of Set 9 | talaya
# Processing Record 27 of Set 9 | maniitsoq
# Processing Record 28 of Set 9 | aden
# Processing Record 29 of Set 9 | malakal
# Processing Record 30 of Set 9 | quatre cocos
# Processing Record 31 of Set 9 | sawakin
# Processing Record 32 of Set 9 | beyneu
# Processing Record 33 of Set 9 | alikalia
# Processing Record 34 of Set 9 | goderich
# Processing Record 35 of Set 9 | zenzeli
# Processing Record 36 of Set 9 | neuquen
# Processing Record 37 of Set 9 | cayenne
# Processing Record 38 of Set 9 | seoul
# Processing Record 39 of Set 9 | beira
# Processing Record 40 of Set 9 | eureka
# Processing Record 41 of Set 9 | dingle
# Processing Record 42 of Set 9 | kalengwa
# City not found. Skipping...
# Processing Record 43 of Set 9 | padang
# Processing Record 44 of Set 9 | rodrigues alves
# Processing Record 45 of Set 9 | erenhot
# Processing Record 46 of Set 9 | rivadavia
# Processing Record 47 of Set 9 | kargasok
# Processing Record 48 of Set 9 | rio blanco
# Processing Record 49 of Set 9 | opunake
# Processing Record 0 of Set 10 | meadow lake
# Processing Record 1 of Set 10 | pangkalanbuun
# Processing Record 2 of Set 10 | albanel
# Processing Record 3 of Set 10 | batticaloa
# Processing Record 4 of Set 10 | nicoya
# Processing Record 5 of Set 10 | marienburg
# Processing Record 6 of Set 10 | virginia beach
# Processing Record 7 of Set 10 | kaz
# Processing Record 8 of Set 10 | lipin bor
# Processing Record 9 of Set 10 | san miguel
# Processing Record 10 of Set 10 | walla walla
# Processing Record 11 of Set 10 | sosnovo-ozerskoye
# Processing Record 12 of Set 10 | prudentopolis
# Processing Record 13 of Set 10 | atambua
# Processing Record 14 of Set 10 | lavrentiya
# Processing Record 15 of Set 10 | dresden
# Processing Record 16 of Set 10 | oranjestad
# Processing Record 17 of Set 10 | temiscaming
# Processing Record 18 of Set 10 | marzuq
# Processing Record 19 of Set 10 | villazon
# Processing Record 20 of Set 10 | komsomolskiy
# Processing Record 21 of Set 10 | kutum
# Processing Record 22 of Set 10 | victor harbor
# Processing Record 23 of Set 10 | mchinji
# Processing Record 24 of Set 10 | melville
# Processing Record 25 of Set 10 | sam roi yot
# Processing Record 26 of Set 10 | loreto
# Processing Record 27 of Set 10 | khandyga
# Processing Record 28 of Set 10 | jaisalmer
# Processing Record 29 of Set 10 | banja luka
# Processing Record 30 of Set 10 | ugoofaaru
# Processing Record 31 of Set 10 | harnosand
# City not found. Skipping...
# Processing Record 32 of Set 10 | moa
# Processing Record 33 of Set 10 | santona
# Processing Record 34 of Set 10 | bairiki
# Processing Record 35 of Set 10 | mount isa
# Processing Record 36 of Set 10 | statesboro
# Processing Record 37 of Set 10 | stavern
# Processing Record 38 of Set 10 | nara
# Processing Record 39 of Set 10 | port keats
# Processing Record 40 of Set 10 | shenkursk
# Processing Record 41 of Set 10 | opuwo
# Processing Record 42 of Set 10 | nouadhibou
# Processing Record 43 of Set 10 | fort nelson
# Processing Record 44 of Set 10 | alice springs
# Processing Record 45 of Set 10 | betare oya
# Processing Record 46 of Set 10 | half moon bay
# City not found. Skipping...
# Processing Record 47 of Set 10 | mamontovo
# Processing Record 48 of Set 10 | baruun-urt
# Processing Record 49 of Set 10 | phalombe
# Processing Record 0 of Set 11 | carolina
# Processing Record 1 of Set 11 | asau
# Processing Record 2 of Set 11 | melfi
# Processing Record 3 of Set 11 | luau
# Processing Record 4 of Set 11 | derzhavinsk
# Processing Record 5 of Set 11 | atkinson
# Processing Record 6 of Set 11 | north bend
# Processing Record 7 of Set 11 | khovu-aksy
# Processing Record 8 of Set 11 | mayumba
# Processing Record 9 of Set 11 | itoman
# Processing Record 10 of Set 11 | nevel
# Processing Record 11 of Set 11 | tres lagoas
# Processing Record 12 of Set 11 | xining
# Processing Record 13 of Set 11 | madanapalle
# Processing Record 14 of Set 11 | hofn
# Processing Record 15 of Set 11 | waipawa
# Processing Record 16 of Set 11 | cuiluan
# City not found. Skipping...
# Processing Record 17 of Set 11 | bull savanna
# Processing Record 18 of Set 11 | san cristobal
# Processing Record 19 of Set 11 | concordia
# Processing Record 20 of Set 11 | de aar
# Processing Record 21 of Set 11 | clyde river
# Processing Record 22 of Set 11 | faya
# Processing Record 23 of Set 11 | maumere
# Processing Record 24 of Set 11 | hukuntsi
# Processing Record 25 of Set 11 | urusha
# Processing Record 26 of Set 11 | rapid valley
# Processing Record 27 of Set 11 | middelburg
# Processing Record 28 of Set 11 | yar-sale
# Processing Record 29 of Set 11 | french harbor
# Processing Record 30 of Set 11 | hamilton
# Processing Record 31 of Set 11 | smiltene
# City not found. Skipping...
# Processing Record 32 of Set 11 | brest
# Processing Record 33 of Set 11 | cockburn town
# Processing Record 34 of Set 11 | izvestkovyy
# Processing Record 35 of Set 11 | vedea
# Processing Record 36 of Set 11 | aranda de duero
# Processing Record 37 of Set 11 | anuchino
# Processing Record 38 of Set 11 | bosaso
# Processing Record 39 of Set 11 | punta de bombon
# Processing Record 40 of Set 11 | bambanglipuro
# Processing Record 41 of Set 11 | caravelas
# Processing Record 42 of Set 11 | strezhevoy
# Processing Record 43 of Set 11 | otane
# Processing Record 44 of Set 11 | chara
# Processing Record 45 of Set 11 | mahajanga
# Processing Record 46 of Set 11 | caxias
# Processing Record 47 of Set 11 | magadi
# Processing Record 48 of Set 11 | las vegas
# Processing Record 49 of Set 11 | sabla
# Processing Record 0 of Set 12 | nurota
# Processing Record 1 of Set 12 | kulu
# Processing Record 2 of Set 12 | las cruces
# Processing Record 3 of Set 12 | faanui
# Processing Record 4 of Set 12 | cavalcante
# Processing Record 5 of Set 12 | khandagayty
# Processing Record 6 of Set 12 | codrington
# Processing Record 7 of Set 12 | paraiso
# Processing Record 8 of Set 12 | baherden
# Processing Record 9 of Set 12 | yaan
# Processing Record 10 of Set 12 | bonavista
# Processing Record 11 of Set 12 | crawfordsville
# Processing Record 12 of Set 12 | asfi
# Processing Record 13 of Set 12 | port arthur
# Processing Record 14 of Set 12 | iralaya
# Processing Record 15 of Set 12 | raymondville
# Processing Record 16 of Set 12 | tombouctou
# Processing Record 17 of Set 12 | fuling
# Processing Record 18 of Set 12 | ishigaki
# City not found. Skipping...
# Processing Record 19 of Set 12 | kungurtug
# Processing Record 20 of Set 12 | santa luzia
# Processing Record 21 of Set 12 | nemuro
# Processing Record 22 of Set 12 | emporia
# Processing Record 23 of Set 12 | filadelfia
# Processing Record 24 of Set 12 | estevan
# Processing Record 25 of Set 12 | pangnirtung
# Processing Record 26 of Set 12 | viransehir
# Processing Record 27 of Set 12 | totma
# Processing Record 28 of Set 12 | bongandanga
# Processing Record 29 of Set 12 | soure
# Processing Record 30 of Set 12 | furmanov
# Processing Record 31 of Set 12 | riachao
# Processing Record 32 of Set 12 | samarai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# # Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create DataFrame

weather_df = pd.DataFrame({"City": city_name, "Lat": latitude, "Lng": longitude, "Max Temp": max_temp, "Humidity": humidity, "Cloudiness": cloudiness, "Wind Speed": wind_speed, "Country": countries, "Date": date_time})
weather_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Bredasdorp -34.5322   20.0403     68.00        68          58
# 1        Husavik  66.0449  -17.3389     39.20        41          20
# 2        Mataura -46.1927  168.8643     50.00        75          72
# 3         Beloha -25.1667   45.0500     68.18        63           2
# 4         Castro -24.7911  -50.0119     77.95        37           3
# ..           ...      ...       ...       ...       ...         ...
# 577  Bongandanga   1.5000   21.0500     78.46        74          77
# 578        Soure  -0.7167  -48.5233     83.61        68          78
# 579     Furmanov  57.2508   41.1058     41.00        75          75
# 580      Riachão  -7.3619  -46.6172     86.32        48          18
# 581      Samarai -10.6167  150.6667     80.40        81          34
#
#      Wind Speed Country        Date
# 0          9.22      ZA  1620148354
# 1          6.91      IS  1620148354
# 2          4.00      NZ  1620148119
# 3         10.33      MG  1620148355
# 4          6.08      BR  1620148355
# ..          ...     ...         ...
# 577        1.95      CD  1620148276
# 578        5.48      BR  1620148499
# 579        6.71      RU  1620148499
# 580        4.61      BR  1620148499
# 581       12.82      PG  1620148500
#
# [582 rows x 9 columns]

# %%
# Export DataFrame as .csv file

weather_df.to_csv("output_data/cities.csv", index = False)

# %%
# Data count
weather_df.count()
# Out:
# City          582
# Lat           582
# Lng           582
# Max Temp      582
# Humidity      582
# Cloudiness    582
# Wind Speed    582
# Country       582
# Date          582
# dtype: int64

# %%
# Display DataFrame
weather_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Bredasdorp -34.5322   20.0403     68.00        68          58        9.22
# 1     Husavik  66.0449  -17.3389     39.20        41          20        6.91
# 2     Mataura -46.1927  168.8643     50.00        75          72        4.00
# 3      Beloha -25.1667   45.0500     68.18        63           2       10.33
# 4      Castro -24.7911  -50.0119     77.95        37           3        6.08
#
#   Country        Date
# 0      ZA  1620148354
# 1      IS  1620148354
# 2      NZ  1620148119
# 3      MG  1620148355
# 4      BR  1620148355

# %% [markdown]
# ## Plotting the Data

# %% [markdown]
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create plot
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], edgecolor = "black")

# Title plot and label axes
plt.title("City Latitude vs. Max Temperature (3/13/2021)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
# Save graph as .png
plt.savefig("City Latitude vs. Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create plot
plt.scatter(weather_df["Lat"], weather_df["Humidity"], edgecolor = "black")

# Title plot and label axes
plt.title("City Latitude vs. Humidity (3/13/2021)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save graph as .png
plt.savefig("City Latitude vs. Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create plot
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], edgecolor = "black")

# Title plot and label axes
plt.title("City Latitude vs. Cloudiness (3/13/2021)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save graph as .png
plt.savefig("City Latitude vs. Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create plot
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], edgecolor = "black")

# Title plot and label axes
plt.title("City Latitude vs. Wind Speed (3/13/2021)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")

# Save graph as .png
plt.savefig("City Latitude vs. Wind Speed.png")

# %% [markdown]
# ## Linear Regression

# %%
# Split data into Northern and Southern hemispheres

northern_hemisphere = weather_df.loc[weather_df["Lat"]>=0]
southern_hemisphere = weather_df.loc[weather_df["Lat"]<0]

# %%
# Define x values and y values
x_values_1 = northern_hemisphere["Lat"]
y_values_1 = northern_hemisphere["Max Temp"]

# Calculate correlation coefficient
correlation = st.pearsonr(x_values_1, y_values_1)
print(f"The r-squared value is: {round(correlation[0],2)}")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values_1, y_values_1)
regress_values = x_values_1 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot with best fit line
plt.scatter(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"], edgecolor = "black")
plt.plot(x_values_1, regress_values,"r-")

# Title plot and label axes and best fit line
plt.title("City Latitude vs. Max Temperature Linear Regression (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.annotate(line_eq,(5, -20),fontsize=15,color="red")

# Save graph as .png
plt.savefig("City Latitude vs. Max Temp Linear Regression Northern Hemisphere.png")
# Out:
# The r-squared value is: -0.86

# %% [markdown]
# There is a very strong negative correlation between latitude and maximum temperature for the northern hemisphere.

# %%
# Define x values and y values
x_values_2 = southern_hemisphere["Lat"]
y_values_2 = southern_hemisphere["Max Temp"]

# Calculate correlation coefficient
correlation = st.pearsonr(x_values_2, y_values_2)
print(f"The r-squared value is: {round(correlation[0],2)}")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values_2, y_values_2)
regress_values = x_values_2 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot with best fit line
plt.scatter(southern_hemisphere["Lat"], southern_hemisphere["Max Temp"], edgecolor = "black")
plt.plot(x_values_2, regress_values,"r-")

# Title plot and label axes and best fit line
plt.title("City Latitude vs. Max Temperature Linear Regression (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.annotate(line_eq,(-25, 50),fontsize=15,color="red")

# Save graph as .png
plt.savefig("City Latitude vs. Max Temp Linear Regression Southern Hemisphere.png")
# Out:
# The r-squared value is: 0.8

# %% [markdown]
# There is a strong positive correlation between latitude and max temperature for the southern hemisphere.

# %% [markdown]
# **Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression**

# %%
# Define x values and y values
x_values_3 = northern_hemisphere["Lat"]
y_values_3 = northern_hemisphere["Humidity"]

# Calculate correlation coefficient
correlation = st.pearsonr(x_values_3, y_values_3)
print(f"The r-squared value is: {round(correlation[0],2)}")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values_3, y_values_3)
regress_values = x_values_3 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot with best fit line
plt.scatter(northern_hemisphere["Lat"], northern_hemisphere["Humidity"], edgecolor = "black")
plt.plot(x_values_3, regress_values,"r-")

# Title plot and label axes and best fit line
plt.title("City Latitude vs. Humidity Linear Regression (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(45, 20),fontsize=15,color="red")

# Save graph as .png
plt.savefig("City Latitude vs. Humidity Linear Regression Northern Hemisphere.png")
# Out:
# The r-squared value is: 0.01

# %% [markdown]
# There is a weak positive correlation between city latitude and humidity for the northern hemisphere.

# %% [markdown]
# **Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression**

# %%
# Define x values and y values
x_values_4 = southern_hemisphere["Lat"]
y_values_4 = southern_hemisphere["Humidity"]

# Calculate correlation coefficient
correlation = st.pearsonr(x_values_4, y_values_4)
print(f"The r-squared value is: {round(correlation[0],2)}")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values_4, y_values_4)
regress_values = x_values_4 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot with best fit line
plt.scatter(southern_hemisphere["Lat"], southern_hemisphere["Humidity"], edgecolor = "black")
plt.plot(x_values_4, regress_values,"r-")

# Title plot and label axes and best fit line
plt.title("City Latitude vs. Humidity Linear Regression (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(-25, 40),fontsize=15,color="red")

# Save graph as .png
plt.savefig("City Latitude vs. Humidity Linear Regression Southern Hemisphere.png")
# Out:
# The r-squared value is: 0.13

# %% [markdown]
# There is a very weak positive correlation between city latitude and humidity for the southern hemisphere.

# %% [markdown]
# **Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression**

# %%
# Define x values and y values
x_values_5 = northern_hemisphere["Lat"]
y_values_5 = northern_hemisphere["Cloudiness"]

# Calculate correlation coefficient
correlation = st.pearsonr(x_values_5, y_values_5)
print(f"The r-squared value is: {round(correlation[0],2)}")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values_5, y_values_5)
regress_values = x_values_5 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot with best fit line
plt.scatter(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"], edgecolor = "black")
plt.plot(x_values_5, regress_values,"r-")

# Title plot and label axes and best fit line
plt.title("City Latitude vs. Cloudiness Linear Regression (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(45, 23),fontsize=15,color="red")
# Save graph as .png
plt.savefig("City Latitude vs. Cloudiness Northern Hemisphere Linear Regression.png")
# Out:
# The r-squared value is: 0.0

# %% [markdown]
# There is a weak positive correlation between city latitude and cloudiness for the northern hemisphere.

# %% [markdown]
# **Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression**

# %%
# Define x values and y values
x_values_6 = southern_hemisphere["Lat"]
y_values_6 = southern_hemisphere["Cloudiness"]

# Calculate correlation coefficient
correlation = st.pearsonr(x_values_6, y_values_6)
print(f"The r-squared value is: {round(correlation[0],2)}")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values_6, y_values_6)
regress_values = x_values_6 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot with best fit line
plt.scatter(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"], edgecolor = "black")
plt.plot(x_values_6, regress_values,"r-")

# Title plot and label axes and best fit line
plt.title("City Latitude vs. Cloudiness Linear Regression (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(-55, 80),fontsize=15,color="red")

# Save graph as .png
plt.savefig("City Latitude vs. Cloudiness Southern Hemisphere Linear Regression.png")
# Out:
# The r-squared value is: 0.22

# %% [markdown]
# There is a weak positive correlation between city latitude and cloudiness for the southern hemisphere.

# %% [markdown]
# **Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression**

# %%
# Define x values and y values
x_values_7 = northern_hemisphere["Lat"]
y_values_7 = northern_hemisphere["Wind Speed"]

# Calculate correlation coefficient
correlation = st.pearsonr(x_values_7, y_values_7)
print(f"The r-squared value is: {round(correlation[0],2)}")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values_7, y_values_7)
regress_values = x_values_7 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot with best fit line
plt.scatter(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"], edgecolor = "black")
plt.plot(x_values_7, regress_values,"r-")

# Title plot and label axes and best fit line
plt.title("City Latitude vs. Wind Speed Linear Regression (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.annotate(line_eq,(45, 33),fontsize=15,color="red")
# Save graph as .png
plt.savefig("City Latitude vs. Wind Speed Northern Hemisphere Linear Regression.png")
# Out:
# The r-squared value is: 0.11

# %% [markdown]
# There is a very weak positive correlation between city latitude and wind speed for the northern hemisphere.

# %% [markdown]
# **Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression**

# %%
# Define x values and y values
x_values_8 = southern_hemisphere["Lat"]
y_values_8 = southern_hemisphere["Wind Speed"]

# Calculate correlation coefficient
correlation = st.pearsonr(x_values_8, y_values_8)
print(f"The r-squared value is: {round(correlation[0],2)}")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values_8, y_values_8)
regress_values = x_values_8 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot with best fit line
plt.scatter(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"], edgecolor = "black")
plt.plot(x_values_8, regress_values,"r-")

# Title plot and label axes and best fit line
plt.title("City Latitude vs. Wind Speed Linear Regression (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.annotate(line_eq,(-22, 17),fontsize=15,color="red")

# Save graph as .png
plt.savefig("City Latitude vs. Wind Speed Southern Hemisphere Linear Regression.png")
# Out:
# The r-squared value is: -0.21

# %% [markdown]
# There is a very weak negative correlation between city latitude and wind speed for the southern hemisphere.

# %% [markdown]
# ## Three observable trends based on data

# %% [markdown]
# * There is a very strong negative correlation between latitude and maximum temperature for the northern hemisphere. This is a logical trend-- the further away from the equator, the weather typically gets increasingly cooler.
# * There is a strong positive correlation between latitude and maximum temperature for the southern hemisphere. This is a logical trend-- the closer to the equator, the weather typically gets increasingly warmer.
# * Aside from the latitude vs. max temperature linear regression for both hemispheres, all other linear regressions revealed a weak or very weak correlation (latitude vs. humidity, cloudiness, and wind speed for both hemispheres).
