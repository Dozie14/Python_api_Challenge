# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
#  ## Generate Cities List

# %%
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 635

# %% [markdown]
# ## Perform API Calls
#
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create empty lists and counters for record and set

city_name = []
latitude = []
longitude = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
countries = []
date_time = []
record_counter = 0
set_counter = 1

# Print initial output as shown

print("Beginning Data Retrieval")
print("-----------------------------")

# Construct query URL

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

# Create for loop

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        countries.append(response["sys"]["country"])
        date_time.append(response["dt"])
        
        if record_counter > 48:
            record_counter = 0
            set_counter = set_counter + 1
        
        else:
            record_counter = record_counter + 1
        
        print(f"Processing Record {record_counter} of Set {set_counter} | {city}")
        
    except (KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nizhnevartovsk
# Processing Record 2 of Set 1 | khatanga
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | berlevag
# Processing Record 7 of Set 1 | san jeronimo
# Processing Record 8 of Set 1 | sitka
# Processing Record 9 of Set 1 | hermanus
# City not found. Skipping...
# Processing Record 10 of Set 1 | ponta do sol
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 13 of Set 1 | tommot
# City not found. Skipping...
# Processing Record 14 of Set 1 | praia
# Processing Record 15 of Set 1 | bocaiuva
# Processing Record 16 of Set 1 | saint-francois
# Processing Record 17 of Set 1 | pullman
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | gat
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | pevek
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | heishan
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | norman wells
# Processing Record 29 of Set 1 | ahipara
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | jining
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | ancud
# Processing Record 35 of Set 1 | fortuna
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | talnakh
# Processing Record 38 of Set 1 | finnsnes
# Processing Record 39 of Set 1 | airai
# Processing Record 40 of Set 1 | mogadishu
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | churapcha
# Processing Record 44 of Set 1 | cidreira
# Processing Record 45 of Set 1 | padang
# Processing Record 46 of Set 1 | los andes
# Processing Record 47 of Set 1 | arraial do cabo
# Processing Record 48 of Set 1 | jevnaker
# Processing Record 49 of Set 1 | mahebourg
# Processing Record 0 of Set 2 | ucluelet
# Processing Record 1 of Set 2 | bambous virieux
# Processing Record 2 of Set 2 | saskylakh
# Processing Record 3 of Set 2 | ilulissat
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 4 | olinda
# Processing Record 44 of Set 4 | upernavik
# Processing Record 45 of Set 4 | ndende
# Processing Record 46 of Set 4 | lebu
# Processing Record 47 of Set 4 | alice springs
# Processing Record 48 of Set 4 | bubaque
# Processing Record 49 of Set 4 | castro
# Processing Record 0 of Set 5 | talcahuano
# Processing Record 1 of Set 5 | constitucion
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 2 of Set 5 | san cristobal
# Processing Record 3 of Set 5 | standish
# Processing Record 4 of Set 5 | sanming
# Processing Record 5 of Set 5 | torbay
# Processing Record 6 of Set 5 | arrifes
# Processing Record 7 of Set 5 | andenes
# Processing Record 8 of Set 5 | chuy
# City not found. Skipping...
# Processing Record 9 of Set 5 | lola
# Processing Record 10 of Set 5 | aksay
# Processing Record 11 of Set 5 | fereydunshahr
# Processing Record 12 of Set 5 | yerofey pavlovich
# Processing Record 13 of Set 5 | nantucket
# City not found. Skipping...
# Processing Record 14 of Set 5 | la palma
# Processing Record 15 of Set 5 | souillac
# Processing Record 16 of Set 5 | codrington
# Processing Record 17 of Set 5 | leh
# Processing Record 18 of Set 5 | puerto del rosario
# Processing Record 19 of Set 5 | flin flon
# City not found. Skipping...
# Processing Record 20 of Set 5 | bure
# Processing Record 21 of Set 5 | san matias
# Processing Record 22 of Set 5 | geilo
# Processing Record 23 of Set 5 | marsh harbour
# Processing Record 24 of Set 5 | sladkovo
# Processing Record 25 of Set 5 | mancio lima
# Processing Record 26 of Set 5 | tiksi
# Processing Record 27 of Set 5 | dayton
# Processing Record 28 of Set 5 | richards bay
# Processing Record 29 of Set 5 | seymchan
# Processing Record 30 of Set 5 | grand gaube
# Processing Record 31 of Set 5 | cherskiy
# Processing Record 32 of Set 5 | halifax
# Processing Record 33 of Set 5 | katsuura
# Processing Record 34 of Set 5 | azanja
# Processing Record 35 of Set 5 | caraquet
# Processing Record 36 of Set 5 | okhotsk
# Processing Record 37 of Set 5 | bredasdorp
# Processing Record 38 of Set 5 | amberley
# Processing Record 39 of Set 5 | sawtell
# Processing Record 40 of Set 5 | sambava
# Processing Record 41 of Set 5 | saint-augustin
# Processing Record 42 of Set 5 | chicama
# Processing Record 43 of Set 5 | acajutla
# Processing Record 44 of Set 5 | pitimbu
# Processing Record 45 of Set 5 | nanortalik
# Processing Record 46 of Set 5 | hirara
# Processing Record 47 of Set 5 | sanmenxia
# Processing Record 48 of Set 5 | taraz
# Processing Record 49 of Set 5 | ishigaki
# Processing Record 0 of Set 6 | quepos
# City not found. Skipping...
# Processing Record 1 of Set 6 | belyye berega
# Processing Record 2 of Set 6 | najran
# Processing Record 3 of Set 6 | conway
# City not found. Skipping...
# Processing Record 4 of Set 6 | jardim
# City not found. Skipping...
# Processing Record 5 of Set 6 | kumluca
# Processing Record 6 of Set 6 | nchelenge
# Processing Record 7 of Set 6 | edson
# Processing Record 8 of Set 6 | lixourion
# City not found. Skipping...
# Processing Record 9 of Set 6 | alofi
# Processing Record 10 of Set 6 | uglich
# Processing Record 11 of Set 6 | manakara
# Processing Record 12 of Set 6 | kaitangata
# Processing Record 13 of Set 6 | bacalar
# Processing Record 14 of Set 6 | orange cove
# Processing Record 15 of Set 6 | bintulu
# Processing Record 16 of Set 6 | yatou
# Processing Record 17 of Set 6 | srandakan
# Processing Record 18 of Set 6 | te anau
# City not found. Skipping...
# Processing Record 19 of Set 6 | baruun-urt
# Processing Record 20 of Set 6 | clarence town
# Processing Record 21 of Set 6 | hamilton
# Processing Record 22 of Set 6 | iquitos
# Processing Record 23 of Set 6 | caravelas
# Processing Record 24 of Set 6 | vilhena
# Processing Record 25 of Set 6 | kloulklubed
# Processing Record 26 of Set 6 | lorengau
# Processing Record 27 of Set 6 | goure
# Processing Record 28 of Set 6 | katobu
# Processing Record 29 of Set 6 | shillong
# Processing Record 30 of Set 6 | porto novo
# Processing Record 31 of Set 6 | vila
# Processing Record 32 of Set 6 | ahuimanu
# Processing Record 33 of Set 6 | ocho rios
# City not found. Skipping...
# Processing Record 34 of Set 6 | gori
# Processing Record 35 of Set 6 | polson
# Processing Record 36 of Set 6 | mount gambier
# Processing Record 37 of Set 6 | kidal
# Processing Record 38 of Set 6 | north bend
# Processing Record 39 of Set 6 | dwarka
# Processing Record 40 of Set 6 | canico
# City not found. Skipping...
# Processing Record 41 of Set 6 | koslan
# Processing Record 42 of Set 6 | guilin
# City not found. Skipping...
# Processing Record 43 of Set 6 | belaya gora
# Processing Record 44 of Set 6 | princeton
# Processing Record 45 of Set 6 | dothan
# Processing Record 46 of Set 6 | owando
# Processing Record 47 of Set 6 | raahe
# Processing Record 48 of Set 6 | puri
# Processing Record 49 of Set 6 | nauta
# Processing Record 0 of Set 7 | komsomolskiy
# Processing Record 1 of Set 7 | unity
# Processing Record 2 of Set 7 | bontang
# Processing Record 3 of Set 7 | flinders
# City not found. Skipping...
# Processing Record 4 of Set 7 | acarau
# Processing Record 5 of Set 7 | erzin
# Processing Record 6 of Set 7 | rongai
# Processing Record 7 of Set 7 | hovd
# City not found. Skipping...
# Processing Record 8 of Set 7 | mehran
# Processing Record 9 of Set 7 | winona
# Processing Record 10 of Set 7 | aksarka
# Processing Record 11 of Set 7 | cabra
# Processing Record 12 of Set 7 | provideniya
# Processing Record 13 of Set 7 | batemans bay
# Processing Record 14 of Set 7 | krusa
# Processing Record 15 of Set 7 | marawi
# Processing Record 16 of Set 7 | buzdyak
# Processing Record 17 of Set 7 | oksfjord
# Processing Record 18 of Set 7 | saint-leu
# Processing Record 19 of Set 7 | arlit
# Processing Record 20 of Set 7 | manono
# Processing Record 21 of Set 7 | grindavik
# Processing Record 22 of Set 7 | inhambane
# Processing Record 23 of Set 7 | aykhal
# Processing Record 24 of Set 7 | kamaishi
# Processing Record 25 of Set 7 | jackson
# Processing Record 26 of Set 7 | douglas
# Processing Record 27 of Set 7 | dudinka
# City not found. Skipping...
# Processing Record 28 of Set 7 | fukue
# Processing Record 29 of Set 7 | mavrovi anovi
# Processing Record 30 of Set 7 | yima
# Processing Record 31 of Set 7 | malanje
# Processing Record 32 of Set 7 | cabedelo
# Processing Record 33 of Set 7 | kipini
# City not found. Skipping...
# City not found. Skipping...
# Processing Record
# Processing Record 41 of Set 11 | tateyama
# Processing Record 42 of Set 11 | urumqi
# Processing Record 43 of Set 11 | korla
# Processing Record 44 of Set 11 | gibara
# Processing Record 45 of Set 11 | muroto
# Processing Record 46 of Set 11 | meulaboh
# Processing Record 47 of Set 11 | biak
# Processing Record 48 of Set 11 | nathdwara
# City not found. Skipping...
# Processing Record 49 of Set 11 | seaham
# Processing Record 0 of Set 12 | banjar
# Processing Record 1 of Set 12 | ilabaya
# Processing Record 2 of Set 12 | boryslav
# Processing Record 3 of Set 12 | gazli
# Processing Record 4 of Set 12 | pimenta bueno
# Processing Record 5 of Set 12 | gazojak
# Processing Record 6 of Set 12 | perth
# Processing Record 7 of Set 12 | qui nhon
# City not found. Skipping...
# Processing Record 8 of Set 12 | sweetwater
# Processing Record 9 of Set 12 | akyab
# Processing Record 10 of Set 12 | bugko
# Processing Record 11 of Set 12 | chumikan
# Processing Record 12 of Set 12 | vostok
# Processing Record 13 of Set 12 | raga
# Processing Record 14 of Set 12 | hojai
# Processing Record 15 of Set 12 | gewane
# Processing Record 16 of Set 12 | mayo
# Processing Record 17 of Set 12 | pryazha
# Processing Record 18 of Set 12 | bahir dar
# Processing Record 19 of Set 12 | great bend
# Processing Record 20 of Set 12 | riviere-au-renard
# Processing Record 21 of Set 12 | axim
# Processing Record 22 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 12 | nuuk
# Processing Record 24 of Set 12 | aleksandrov gay
# Processing Record 25 of Set 12 | cap malheureux
# Processing Record 26 of Set 12 | daru
# Processing Record 27 of Set 12 | polunochnoye
# Processing Record 28 of Set 12 | wilmington
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 12 | tyukalinsk
# Processing Record 30 of Set 12 | caraz
# Processing Record 31 of Set 12 | esfarayen
# Processing Record 32 of Set 12 | zadar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ## Convert Raw Data to DataFrame
#
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create DataFrame

weather_df = pd.DataFrame({"City": city_name, "Lat": latitude, "Lng": longitude, "Max Temp": max_temp, "Humidity": humidity, "Cloudiness": cloudiness, "Wind Speed": wind_speed, "Country": countries, "Date": date_time})
weather_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Nizhnevartovsk  60.9344   76.5531     30.20        69           0
# 1          Khatanga  71.9667  102.5000     23.36        82          88
# 2         Hithadhoo  -0.6000   73.0833     83.35        70         100
# 3            Hobart -42.8794  147.3294     41.00        93          20
# 4         Jamestown  42.0970  -79.2353     62.01        82          90
# ..              ...      ...       ...       ...       ...         ...
# 577      Wilmington  34.2257  -77.9447     84.20        61           1
# 578      Tyukalinsk  55.8732   72.1967     39.94        53           4
# 579           Caraz  -9.0486  -77.8100     61.50        92          98
# 580       Esfarāyen  37.0765   57.5101     55.40        88          90
# 581           Zadar  44.1197   15.2422     46.40        87           0
#
#      Wind Speed Country        Date
# 0          4.47      RU  1620077501
# 1         13.31      RU  1620077256
# 2          5.35      MV  1620077501
# 3          9.22      AU  1620077502
# 4         14.97      US  1620077502
# ..          ...     ...         ...
# 577       11.50      US  1620077589
# 578        6.15      RU  1620077641
# 579        5.17      PE  1620077641
# 580        2.30      IR  1620077641
# 581        6.91      HR  1620077642
#
# [582 rows x 9 columns]

# %%
# Export DataFrame as .csv file

weather_df.to_csv("output_data/cities.csv", index = False)

# %%
# Data count
weather_df.count()
# Out:
# City          582
# Lat           582
# Lng           582
# Max Temp      582
# Humidity      582
# Cloudiness    582
# Wind Speed    582
# Country       582
# Date          582
# dtype: int64

# %%
# Display DataFrame
weather_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Nizhnevartovsk  60.9344   76.5531     30.20        69           0
# 1        Khatanga  71.9667  102.5000     23.36        82          88
# 2       Hithadhoo  -0.6000   73.0833     83.35        70         100
# 3          Hobart -42.8794  147.3294     41.00        93          20
# 4       Jamestown  42.0970  -79.2353     62.01        82          90
#
#    Wind Speed Country        Date
# 0        4.47      RU  1620077501
# 1       13.31      RU  1620077256
# 2        5.35      MV  1620077501
# 3        9.22      AU  1620077502
# 4       14.97      US  1620077502

# %% [markdown]
# ## Plotting the Data

# %% [markdown]
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create plot
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], edgecolor = "black")

# Title plot and label axes
plt.title("City Latitude vs. Max Temperature (3/13/2021)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

# Save graph as .png
plt.savefig("City Latitude vs. Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create plot
plt.scatter(weather_df["Lat"], weather_df["Humidity"], edgecolor = "black")

# Title plot and label axes
plt.title("City Latitude vs. Humidity (3/13/2021)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save graph as .png
plt.savefig("City Latitude vs. Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create plot
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], edgecolor = "black")

# Title plot and label axes
plt.title("City Latitude vs. Cloudiness (3/13/2021)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save graph as .png
plt.savefig("City Latitude vs. Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create plot
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], edgecolor = "black")

# Title plot and label axes
plt.title("City Latitude vs. Wind Speed (3/13/2021)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")

# Save graph as .png
plt.savefig("City Latitude vs. Wind Speed.png")

# %% [markdown]
# ## Linear Regression

# %%
# Split data into Northern and Southern hemispheres

northern_hemisphere = weather_df.loc[weather_df["Lat"]>=0]
southern_hemisphere = weather_df.loc[weather_df["Lat"]<0]

# %%
# Define x values and y values
x_values_1 = northern_hemisphere["Lat"]
y_values_1 = northern_hemisphere["Max Temp"]

# Calculate correlation coefficient
correlation = st.pearsonr(x_values_1, y_values_1)
print(f"The r-squared value is: {round(correlation[0],2)}")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values_1, y_values_1)
regress_values = x_values_1 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot with best fit line
plt.scatter(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"], edgecolor = "black")
plt.plot(x_values_1, regress_values,"r-")

# Title plot and label axes and best fit line
plt.title("City Latitude vs. Max Temperature Linear Regression (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.annotate(line_eq,(5, -20),fontsize=15,color="red")

# Save graph as .png
plt.savefig("City Latitude vs. Max Temp Linear Regression Northern Hemisphere.png")
# Out:
# The r-squared value is: -0.86

# %% [markdown]
# There is a very strong negative correlation between latitude and maximum temperature for the northern hemisphere.

# %%
# Define x values and y values
x_values_2 = southern_hemisphere["Lat"]
y_values_2 = southern_hemisphere["Max Temp"]

# Calculate correlation coefficient
correlation = st.pearsonr(x_values_2, y_values_2)
print(f"The r-squared value is: {round(correlation[0],2)}")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values_2, y_values_2)
regress_values = x_values_2 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot with best fit line
plt.scatter(southern_hemisphere["Lat"], southern_hemisphere["Max Temp"], edgecolor = "black")
plt.plot(x_values_2, regress_values,"r-")

# Title plot and label axes and best fit line
plt.title("City Latitude vs. Max Temperature Linear Regression (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.annotate(line_eq,(-25, 50),fontsize=15,color="red")

# Save graph as .png
plt.savefig("City Latitude vs. Max Temp Linear Regression Southern Hemisphere.png")
# Out:
# The r-squared value is: 0.73

# %% [markdown]
# There is a strong positive correlation between latitude and max temperature for the southern hemisphere.

# %% [markdown]
# **Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression**

# %%
# Define x values and y values
x_values_3 = northern_hemisphere["Lat"]
y_values_3 = northern_hemisphere["Humidity"]

# Calculate correlation coefficient
correlation = st.pearsonr(x_values_3, y_values_3)
print(f"The r-squared value is: {round(correlation[0],2)}")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values_3, y_values_3)
regress_values = x_values_3 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot with best fit line
plt.scatter(northern_hemisphere["Lat"], northern_hemisphere["Humidity"], edgecolor = "black")
plt.plot(x_values_3, regress_values,"r-")

# Title plot and label axes and best fit line
plt.title("City Latitude vs. Humidity Linear Regression (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(45, 20),fontsize=15,color="red")

# Save graph as .png
plt.savefig("City Latitude vs. Humidity Linear Regression Northern Hemisphere.png")
# Out:
# The r-squared value is: 0.01

# %% [markdown]
# There is a weak positive correlation between city latitude and humidity for the northern hemisphere.

# %% [markdown]
# **Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression**

# %%
# Define x values and y values
x_values_4 = southern_hemisphere["Lat"]
y_values_4 = southern_hemisphere["Humidity"]

# Calculate correlation coefficient
correlation = st.pearsonr(x_values_4, y_values_4)
print(f"The r-squared value is: {round(correlation[0],2)}")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values_4, y_values_4)
regress_values = x_values_4 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot with best fit line
plt.scatter(southern_hemisphere["Lat"], southern_hemisphere["Humidity"], edgecolor = "black")
plt.plot(x_values_4, regress_values,"r-")

# Title plot and label axes and best fit line
plt.title("City Latitude vs. Humidity Linear Regression (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq,(-25, 40),fontsize=15,color="red")

# Save graph as .png
plt.savefig("City Latitude vs. Humidity Linear Regression Southern Hemisphere.png")
# Out:
# The r-squared value is: 0.35

# %% [markdown]
# There is a very weak positive correlation between city latitude and humidity for the southern hemisphere.

# %% [markdown]
# **Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression**

# %%
# Define x values and y values
x_values_5 = northern_hemisphere["Lat"]
y_values_5 = northern_hemisphere["Cloudiness"]

# Calculate correlation coefficient
correlation = st.pearsonr(x_values_5, y_values_5)
print(f"The r-squared value is: {round(correlation[0],2)}")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values_5, y_values_5)
regress_values = x_values_5 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot with best fit line
plt.scatter(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"], edgecolor = "black")
plt.plot(x_values_5, regress_values,"r-")

# Title plot and label axes and best fit line
plt.title("City Latitude vs. Cloudiness Linear Regression (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(45, 23),fontsize=15,color="red")

# Save graph as .png
plt.savefig("City Latitude vs. Cloudiness Northern Hemisphere Linear Regression.png")
# Out:
# The r-squared value is: -0.02

# %% [markdown]
# There is a weak positive correlation between city latitude and cloudiness for the northern hemisphere.

# %% [markdown]
# **Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression**

# %%
# Define x values and y values
x_values_6 = southern_hemisphere["Lat"]
y_values_6 = southern_hemisphere["Cloudiness"]

# Calculate correlation coefficient
correlation = st.pearsonr(x_values_6, y_values_6)
print(f"The r-squared value is: {round(correlation[0],2)}")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values_6, y_values_6)
regress_values = x_values_6 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot with best fit line
plt.scatter(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"], edgecolor = "black")
plt.plot(x_values_6, regress_values,"r-")

# Title plot and label axes and best fit line
plt.title("City Latitude vs. Cloudiness Linear Regression (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq,(-55, 80),fontsize=15,color="red")

# Save graph as .png
plt.savefig("City Latitude vs. Cloudiness Southern Hemisphere Linear Regression.png")
# Out:
# The r-squared value is: 0.22

# %% [markdown]
# There is a weak positive correlation between city latitude and cloudiness for the southern hemisphere.

# %% [markdown]
# **Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression**

# %%
# Define x values and y values
x_values_7 = northern_hemisphere["Lat"]
y_values_7 = northern_hemisphere["Wind Speed"]

# Calculate correlation coefficient
correlation = st.pearsonr(x_values_7, y_values_7)
print(f"The r-squared value is: {round(correlation[0],2)}")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values_7, y_values_7)
regress_values = x_values_7 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot with best fit line
plt.scatter(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"], edgecolor = "black")
plt.plot(x_values_7, regress_values,"r-")

# Title plot and label axes and best fit line
plt.title("City Latitude vs. Wind Speed Linear Regression (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.annotate(line_eq,(45, 33),fontsize=15,color="red")

# Save graph as .png
plt.savefig("City Latitude vs. Wind Speed Northern Hemisphere Linear Regression.png")
# Out:
# The r-squared value is: 0.05

# %% [markdown]
# There is a very weak positive correlation between city latitude and wind speed for the northern hemisphere.

# %% [markdown]
# **Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression**

# %%
# Define x values and y values
x_values_8 = southern_hemisphere["Lat"]
y_values_8 = southern_hemisphere["Wind Speed"]

# Calculate correlation coefficient
correlation = st.pearsonr(x_values_8, y_values_8)
print(f"The r-squared value is: {round(correlation[0],2)}")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values_8, y_values_8)
regress_values = x_values_8 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot with best fit line
plt.scatter(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"], edgecolor = "black")
plt.plot(x_values_8, regress_values,"r-")

# Title plot and label axes and best fit line
plt.title("City Latitude vs. Wind Speed Linear Regression (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.annotate(line_eq,(-22, 17),fontsize=15,color="red")

# Save graph as .png
plt.savefig("City Latitude vs. Wind Speed Southern Hemisphere Linear Regression.png")
# Out:
# The r-squared value is: -0.24

# %% [markdown]
# There is a very weak negative correlation between city latitude and wind speed for the southern hemisphere.
#
# ## Three observable trends based on data
#
# * There is a very strong negative correlation between latitude and maximum temperature for the northern hemisphere. This is a logical trend-- the further away from the equator, the weather typically gets increasingly cooler.
# * There is a strong positive correlation between latitude and maximum temperature for the southern hemisphere. This is a logical trend-- the closer to the equator, the weather typically gets increasingly warmer.
# * Aside from the latitude vs. max temperature linear regression for both hemispheres, all other linear regressions revealed a weak or very weak correlation (latitude vs. humidity, cloudiness, and wind speed for both hemispheres).
